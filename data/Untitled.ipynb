# %%
import os

# %%
train = open('ptb.train.txt', encoding='utf-8').read()
test = open('ptb.test.txt', encoding='utf-8').read()
valid = open('ptb.valid.txt', encoding='utf-8').read()

char_train = open('ptb.char.train.txt', encoding='utf-8').read()
char_test = open('ptb.char.test.txt', encoding='utf-8').read()
char_valid = open('ptb.char.valid.txt', encoding='utf-8').read()

# %%
print (len(set(train)))
print (len(set(test)))
print (len(set(valid)))
print (len(set(char_train)))
print (len(set(char_test)))
print (len(set(char_valid)))
# Out:
# 50
# 48
# 50
# 51
# 49
# 51

# %%
print (len(set(train.split(' '))))
print (len(set(valid.split(' '))))
print (len(set(test.split(' '))))
# Out:
# 10001
# 6023
# 6050

# %%
print (len(train.split(' ')))
print (len(valid.split(' ')))
print (len(test.split(' ')))
# Out:
# 929590
# 73761
# 82431

# %%
char_train = open('ptb.char.train.txt', encoding='utf-8').read()
char_test = open('ptb.char.test.txt', encoding='utf-8').read()
char_valid = open('ptb.char.valid.txt', encoding='utf-8').read()

chars = char_valid.replace(' ', '')
d = open("ptb.char.valid.strip.txt", "w")
d.write(chars)
# Out:
# 393042

# %%
chars = char_test.replace(' ','')

# %%
import torch
from torch.autograd import Variable
print(torch.__version__)
# Out:
# 0.5.0a0+7450e91

# %%
a = torch.tensor([1,1])
b = Variable(a)

# %%
print (a.type())
print (b.type())
# Out:
# torch.LongTensor
# torch.LongTensor

# %%
[i for i, c in enumerate(chars) if c == '.']
# Out:
# [1232,
#  1716,
#  2034,
#  2546,
#  2548,
#  2868,
#  5469,
#  5471,
#  5501,
#  5503,
#  5724,
#  5966,
#  6291,
#  6293,
#  6872,
#  6996,
#  7042,
#  7313,
#  7358,
#  7682,
#  7728,
#  8914,
#  9204,
#  9414,
#  9525,
#  9828,
#  10302,
#  10413,
#  10468,
#  10470,
#  10483,
#  10746,
#  10762,
#  10841,
#  10952,
#  11011,
#  11013,
#  11110,
#  11112,
#  11149,
#  11245,
#  11247,
#  11345,
#  11347,
#  11395,
#  11517,
#  11519,
#  11714,
#  11800,
#  11802,
#  11849,
#  11862,
#  11865,
#  11867,
#  12015,
#  12017,
#  12099,
#  12179,
#  12336,
#  12338,
#  13083,
#  13085,
#  13149,
#  13281,
#  13364,
#  13473,
#  13486,
#  13568,
#  13602,
#  13654,
#  13670,
#  13736,
#  13790,
#  13902,
#  13915,
#  14142,
#  14311,
#  14487,
#  14872,
#  14895,
#  14984,
#  14986,
#  15925,
#  17052,
#  17883,
#  17906,
#  18286,
#  18329,
#  19160,
#  19187,
#  19805,
#  20250,
#  20587,
#  21217,
#  21318,
#  21820,
#  22059,
#  22311,
#  22429,
#  22888,
#  22890,
#  22907,
#  23680,
#  24058,
#  24645,
#  25470,
#  25592,
#  26067,
#  26069,
#  26111,
#  26455,
#  26476,
#  26758,
#  27415,
#  27677,
#  28017,
#  28277,
#  29214,
#  29718,
#  29779,
#  29849,
#  29851,
#  29950,
#  30418,
#  30840,
#  31129,
#  31161,
#  32010,
#  32296,
#  32577,
#  32652,
#  32939,
#  33344,
#  34143,
#  34247,
#  34294,
#  34662,
#  34664,
#  34779,
#  34799,
#  36366,
#  37443,
#  37485,
#  39574,
#  39631,
#  39728,
#  39730,
#  39956,
#  40019,
#  40021,
#  40188,
#  40497,
#  41143,
#  41996,
#  41998,
#  42185,
#  42187,
#  42421,
#  42423,
#  42504,
#  42602,
#  42604,
#  42629,
#  42652,
#  42654,
#  42991,
#  42993,
#  43136,
#  43138,
#  43506,
#  43508,
#  43678,
#  43680,
#  43725,
#  43727,
#  43927,
#  43929,
#  44104,
#  44106,
#  44298,
#  44300,
#  44407,
#  44409,
#  44526,
#  44528,
#  44760,
#  44762,
#  44880,
#  44882,
#  45233,
#  45235,
#  45524,
#  45810,
#  46043,
#  46172,
#  46381,
#  46655,
#  46997,
#  47210,
#  47490,
#  47657,
#  48039,
#  48332,
#  48364,
#  48366,
#  48641,
#  49369,
#  49371,
#  50883,
#  50885,
#  50940,
#  50942,
#  51098,
#  51100,
#  51201,
#  51422,
#  51465,
#  51467,
#  51539,
#  51541,
#  51683,
#  51685,
#  51738,
#  51740,
#  51816,
#  51970,
#  51984,
#  52210,
#  52212,
#  52246,
#  52792,
#  52811,
#  53165,
#  53183,
#  53533,
#  53870,
#  54097,
#  54099,
#  54644,
#  54703,
#  54705,
#  54754,
#  54756,
#  54807,
#  54809,
#  54932,
#  54934,
#  55050,
#  55250,
#  56363,
#  56598,
#  57025,
#  57063,
#  57092,
#  57104,
#  57427,
#  57429,
#  57490,
#  57492,
#  58117,
#  58480,
#  58494,
#  58871,
#  58873,
#  60877,
#  61454,
#  61469,
#  61637,
#  61639,
#  61771,
#  62353,
#  62355,
#  62375,
#  62377,
#  62649,
#  62651,
#  63409,
#  63411,
#  63578,
#  64198,
#  64235,
#  65668,
#  65731,
#  65770,
#  66051,
#  66098,
#  66252,
#  66525,
#  66538,
#  66554,
#  66645,
#  66711,
#  66724,
#  66774,
#  66865,
#  66918,
#  67063,
#  67228,
#  67318,
#  67558,
#  67609,
#  67630,
#  67668,
#  68828,
#  68830,
#  69167,
#  69169,
#  70028,
#  70227,
#  70231,
#  71151,
#  71153,
#  71345,
#  71621,
#  71623,
#  72039,
#  72041,
#  72313,
#  72315,
#  74366,
#  75190,
#  75688,
#  76257,
#  76263,
#  76355,
#  76509,
#  76916,
#  77007,
#  77270,
#  77318,
#  77394,
#  77472,
#  77867,
#  77925,
#  78133,
#  78243,
#  78413,
#  78415,
#  78650,
#  78739,
#  78892,
#  78983,
#  78985,
#  79116,
#  79183,
#  80062,
#  80313,
#  80331,
#  80764,
#  81008,
#  81018,
#  81048,
#  81092,
#  81171,
#  81299,
#  81387,
#  81401,
#  81490,
#  81500,
#  81502,
#  81580,
#  81582,
#  81608,
#  82085,
#  83078,
#  83091,
#  83210,
#  83212,
#  83223,
#  83825,
#  83927,
#  84872,
#  85365,
#  85586,
#  86190,
#  86256,
#  86537,
#  86755,
#  86952,
#  87349,
#  87924,
#  87984,
#  87986,
#  88315,
#  88317,
#  88434,
#  88436,
#  88684,
#  88698,
#  88700,
#  88910,
#  88912,
#  89512,
#  89852,
#  90459,
#  90461,
#  90528,
#  90558,
#  90775,
#  92011,
#  92013,
#  92123,
#  93244,
#  93853,
#  93868,
#  94304,
#  94522,
#  94642,
#  94802,
#  94804,
#  94850,
#  95760,
#  95793,
#  96429,
#  96445,
#  96464,
#  96485,
#  96518,
#  96649,
#  96664,
#  96836,
#  97131,
#  97453,
#  97830,
#  97923,
#  97925,
#  97999,
#  98275,
#  98926,
#  98928,
#  99307,
#  99364,
#  99418,
#  99723,
#  99725,
#  100357,
#  101097,
#  101172,
#  101433,
#  101982,
#  102149,
#  103064,
#  103556,
#  103851,
#  104435,
#  106059,
#  106404,
#  106406,
#  106428,
#  106451,
#  106955,
#  108244,
#  108246,
#  108574,
#  109422,
#  109851,
#  110198,
#  110506,
#  110889,
#  110963,
#  111071,
#  111587,
#  111589,
#  111602,
#  112475,
#  113186,
#  113495,
#  113884,
#  113914,
#  114476,
#  114478,
#  115018,
#  115029,
#  115443,
#  115454,
#  115456,
#  115594,
#  115812,
#  119021,
#  120000,
#  120416,
#  120535,
#  120548,
#  120550,
#  121833,
#  122416,
#  122665,
#  122677,
#  122738,
#  123007,
#  123067,
#  123373,
#  123448,
#  123564,
#  123638,
#  123655,
#  123741,
#  123898,
#  123903,
#  123923,
#  123963,
#  124070,
#  124077,
#  124079,
#  124119,
#  124475,
#  125342,
#  125384,
#  125898,
#  126197,
#  126683,
#  126847,
#  127128,
#  127175,
#  127194,
#  127196,
#  127495,
#  128485,
#  128710,
#  130179,
#  130204,
#  131585,
#  131800,
#  131813,
#  131970,
#  131972,
#  131981,
#  131983,
#  132028,
#  133450,
#  133910,
#  133971,
#  133973,
#  134070,
#  134125,
#  134786,
#  134854,
#  135055,
#  135840,
#  135995,
#  136514,
#  137369,
#  137371,
#  138072,
#  138606,
#  138714,
#  140639,
#  140641,
#  141172,
#  141174,
#  141303,
#  141305,
#  142109,
#  142111,
#  142475,
#  142477,
#  143326,
#  143401,
#  143502,
#  143575,
#  143608,
#  143697,
#  143777,
#  143779,
#  143796,
#  143918,
#  143920,
#  144168,
#  145045,
#  145861,
#  146245,
#  149348,
#  150152,
#  150223,
#  150738,
#  151616,
#  152625,
#  153645,
#  154010,
#  154182,
#  154409,
#  155016,
#  155298,
#  156251,
#  156253,
#  157620,
#  157622,
#  157746,
#  158275,
#  158277,
#  158853,
#  158855,
#  160533,
#  160535,
#  161627,
#  161629,
#  162265,
#  162267,
#  163332,
#  163334,
#  163635,
#  163637,
#  163683,
#  163764,
#  164410,
#  164412,
#  165874,
#  165920,
#  165922,
#  166028,
#  166030,
#  166526,
#  166750,
#  166752,
#  167298,
#  167990,
#  168313,
#  168315,
#  168387,
#  168389,
#  168520,
#  168522,
#  168573,
#  168575,
#  168773,
#  168854,
#  168856,
#  168885,
#  168887,
#  169051,
#  169141,
#  169143,
#  169546,
#  170324,
#  170830,
#  171443,
#  171837,
#  172076,
#  172088,
#  172114,
#  172191,
#  172260,
#  172386,
#  172711,
#  173095,
#  173814,
#  174209,
#  174289,
#  174845,
#  175597,
#  176107,
#  176193,
#  176287,
#  181072,
#  181074,
#  181643,
#  182117,
#  183635,
#  184449,
#  184451,
#  184471,
#  184653,
#  184841,
#  185157,
#  185297,
#  185398,
#  185459,
#  185666,
#  185809,
#  185962,
#  187155,
#  187494,
#  187534,
#  187629,
#  189150,
#  189275,
#  189494,
#  189824,
#  190904,
#  190945,
#  190971,
#  191008,
#  191019,
#  191145,
#  191822,
#  192325,
#  192711,
#  193030,
#  194202,
#  195231,
#  195332,
#  195714,
#  195844,
#  196869,
#  196916,
#  197054,
#  197579,
#  199246,
#  199248,
#  199536,
#  199730,
#  199732,
#  200014,
#  200151,
#  201087,
#  201095,
#  201097,
#  201116,
#  201309,
#  201830,
#  201862,
#  202302,
#  202562,
#  202853,
#  203256,
#  203516,
#  203520,
#  204341,
#  204393,
#  204869,
#  205334,
#  205453,
#  205492,
#  205543,
#  206572,
#  207585,
#  207677,
#  208031,
#  208229,
#  208231,
#  208462,
#  208464,
#  208548,
#  209052,
#  209280,
#  209395,
#  209475,
#  209766,
#  209768,
#  209851,
#  209884,
#  209982,
#  210138,
#  210811,
#  210970,
#  211155,
#  211497,
#  211639,
#  212106,
#  212254,
#  212286,
#  212571,
#  213289,
#  213327,
#  214229,
#  214240,
#  214242,
#  214978,
#  215350,
#  215545,
#  217013,
#  217537,
#  217800,
#  218112,
#  219745,
#  220195,
#  220786,
#  221202,
#  221428,
#  221901,
#  222202,
#  222421,
#  223960,
#  223962,
#  224142,
#  224144,
#  224361,
#  224363,
#  224622,
#  225077,
#  225079,
#  226060,
#  226062,
#  227487,
#  227551,
#  227591,
#  228191,
#  228238,
#  228751,
#  229115,
#  229721,
#  229778,
#  230996,
#  231085,
#  231614,
#  232017,
#  232027,
#  232029,
#  232107,
#  232109,
#  232326,
#  232385,
#  232757,
#  232786,
#  232788,
#  235075,
#  235207,
#  235209,
#  235604,
#  236051,
#  238190,
#  238357,
#  238836,
#  239107,
#  239443,
#  239965,
#  240724,
#  240740,
#  241060,
#  241438,
#  241440,
#  241761,
#  241883,
#  241885,
#  242187,
#  242275,
#  242350,
#  242442,
#  242548,
#  242607,
#  242820,
#  242890,
#  242935,
#  243090,
#  243092,
#  243473,
#  244433,
#  244921,
#  244966,
#  245316,
#  245563,
#  245686,
#  245688,
#  246351,
#  246401,
#  246600,
#  247591,
#  248164,
#  248274,
#  248411,
#  249357,
#  249538,
#  249684,
#  250477,
#  250489,
#  250503,
#  250851,
#  251142,
#  251205,
#  251207,
#  251476,
#  253318,
#  253588,
#  253590,
#  253662,
#  254118,
#  255409,
#  255411,
#  255597,
#  255744,
#  255786,
#  255939,
#  256055,
#  256135,
#  256217,
#  257238,
#  257408,
#  257512,
#  257540,
#  257552,
#  257568,
#  257679,
#  257844,
#  257864,
#  257890,
#  258091,
#  258220,
#  258305,
#  258398,
#  258400,
#  258498,
#  258500,
#  258644,
#  258840,
#  259805,
#  259830,
#  260033,
#  260303,
#  260331,
#  260419,
#  260421,
#  260480,
#  260520,
#  260649,
#  260959,
#  261007,
#  261557,
#  261606,
#  261608,
#  261713,
#  261873,
#  262155,
#  262517,
#  263098,
#  263192,
#  263194,
#  263206,
#  263272,
#  263462,
#  263524,
#  263656,
#  263861,
#  263863,
#  264155,
#  264302,
#  264432,
#  264434,
#  264470,
#  264472,
#  265654,
#  265668,
#  266073,
#  267393,
#  267692,
#  267694,
#  267874,
#  267876,
#  268932,
#  268934,
#  269339,
#  269341,
#  269571,
#  269573,
#  269994,
#  270171,
#  270697,
#  271949,
#  272167,
#  272169,
#  272612,
#  272627,
#  273450,
#  273852,
#  274094,
#  274390,
#  274653,
#  274758,
#  274984,
#  275186,
#  275359,
#  275361,
#  275369,
#  275449,
#  276192,
#  276721,
#  276747,
#  276751,
#  276859,
#  277313,
#  277596,
#  277598,
#  277609,
#  277611,
#  277725,
#  277766,
#  277844,
#  277976,
#  278017,
#  278124,
#  278163,
#  278459,
#  278930,
#  279158,
#  280412,
#  281254,
#  282228,
#  283194,
#  285114,
#  285116,
#  287810,
#  287812,
#  287906,
#  287908,
#  288030,
#  289209,
#  289389,
#  289449,
#  289451,
#  289575,
#  289577,
#  ...]

# %%
def find_interval(array, idx):
    return a

# %%
from bisect import bisect_left
from bisect import bisect_right
from bisect import bisect

# %%
a = [2,10,15,23]
a = [0] + a

# not found
bisect_right
bisect_right + 1

# found


for i in range(0, 24):
    lead_marker_idx = max(0, bisect_left(a, i)-1)
    tail_marker_idx = max(0, bisect_right(a, i))
    
    if lead_marker_idx == tail_marker_idx:
        print (0)
    else:
        print (lead_marker_idx)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-270-59ae8d0c2004> in <module>()
#       4 # not found
#       5 bisect_right
# ----> 6 bisect_right + 1
#       7
#       8 # found
#
# TypeError: unsupported operand type(s) for +: 'builtin_function_or_method' and 'int'

# %%
[1,2] + [3,4,5]
# Out:
# [1, 2, 3, 4, 5]

# %%
b = torch.Tensor(2,2,2)

# %%
print (b)
#print (b[:, 1, -1])
print (b[:, 1, :])
# Out:
# tensor([[[ 0.0000e+00,  4.6566e-10],
#          [ 4.1856e+06, -3.6902e+19]],
#
#         [[ 2.8026e-45,  4.6566e-10],
#          [ 4.1805e+06,  1.8654e-40]]])
# tensor([[ 4.1856e+06, -3.6902e+19],
#         [ 4.1805e+06,  1.8654e-40]])

# %%
a = [2,10,15,23]
a = [-1] + a + [a[-1]+1]
t = 2

for i in range(0, 24):
    l = bisect_left(a, i)
    o = 1000
    if a[l] == i:
        o *= 1
    else:
        l1 = a[l - 1]
        l2 = a[l]
        o *= (i - l1) / (l2 - l1)
    print (o)
# Out:
# 333.3333333333333
# 666.6666666666666
# 1000
# 125.0
# 250.0
# 375.0
# 500.0
# 625.0
# 750.0
# 875.0
# 1000
# 200.0
# 400.0
# 600.0
# 800.0
# 1000
# 125.0
# 250.0
# 375.0
# 500.0
# 625.0
# 750.0
# 875.0
# 1000

# %%
import torch
torch.Tensor([23]) / 100
# Out:
# tensor([ 0.2300])

# %%
aa = {'a':'b'}

# %%
a = [1,2,3,4]

# %%
a = torch.Tensor([11,23,34,4])
values, indices = a.min(0)
print (i, k)
# Out:
# tensor(4.) tensor(3)
